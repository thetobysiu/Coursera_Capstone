# %% [markdown]
# # Data that will be used

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Total case and trends

# %%
total_case_df = pd.read_json('https://api.data.gov.hk/v2/filter?q=%7B%22resource%22%3A%22http%3A%2F%2Fwww.chp.gov.hk%2Ffiles%2Fmisc%2Flatest_situation_of_reported_cases_wuhan_eng.csv%22%2C%22section%22%3A1%2C%22format%22%3A%22json%22%7D')

# %%
total_case_df[:5]
# Out:
#   As of date As of time  Number of confirmed cases  Number of ruled out cases  \
# 0   8/1/2020      12:00                          0                         21
# 1   9/1/2020      12:00                          0                         25
# 2  10/1/2020      12:00                          0                         31
# 3  11/1/2020      12:00                          0                         46
# 4  12/1/2020      12:00                          0                         51
#
#    Number of cases still hospitalised for investigation  \
# 0                                                 17
# 1                                                 23
# 2                                                 23
# 3                                                 15
# 4                                                 16
#
#    Number of cases fulfilling the reporting criteria  Number of death cases  \
# 0                                                 38                      0
# ...

# %% [markdown]
# Show the trend of confirmed cases (linear, cubic, quadratic...)
# <p> Show the trend of discharge cases/ accumulative

# %% [markdown]
# # Buildings and related cases

# %%
district_building_df = pd.read_json('https://api.data.gov.hk/v2/filter?q=%7B%22resource%22%3A%22http%3A%2F%2Fwww.chp.gov.hk%2Ffiles%2Fmisc%2Fbuilding_list_eng.csv%22%2C%22section%22%3A1%2C%22format%22%3A%22json%22%2C%22sorts%22%3A%5B%5B1%2C%22asc%22%5D%5D%7D')

# %%
district_building_df[:10]
# Out:
#             District                                    Building name  \
# 0  Central & Western  Kellett View Town Houses, 65 Mount Kellett Road
# 1  Central & Western                                Island Shangri-La
# 2  Central & Western               Emerald Garden, 86 Pok Fu Lam Road
# 3  Central & Western              Rich View Terrace, 26 Square Street
# 4  Central & Western                                3A Tregunter Path
# 5  Central & Western                  Seymour Place, 60 Robinson Road
# 6  Central & Western      Kwong Ga Factory Building (non-residential)
# 7  Central & Western                  Pacific Place (non-residential)
# 8  Central & Western                The Grand Stage (non-residential)
# 9  Central & Western         Bank of China Building (non-residential)
#
#   Last date of residence of the case(s) Related probable/confirmed cases
# 0                             14/3/2020                    Case 147, 148
# ...

# %% [markdown]
# Data visualization of districts with cases using Folum
# <p> Trend of cases in each districts

# %% [markdown]
# # Details of cases

# %%
case_detail_df = pd.read_json('https://api.data.gov.hk/v2/filter?q=%7B%22resource%22%3A%22http%3A%2F%2Fwww.chp.gov.hk%2Ffiles%2Fmisc%2Fenhanced_sur_pneumonia_wuhan_eng.csv%22%2C%22section%22%3A1%2C%22format%22%3A%22json%22%7D')

# %%
case_detail_df[:10]
# Out:
#    Case no. Report date Date of onset Gender  Age   Name of hospital admitted  \
# 0         1   23/1/2020     21/1/2020      M   39  Princess Margaret Hospital
# 1         2   23/1/2020     18/1/2020      M   56  Princess Margaret Hospital
# 2         3   24/1/2020     20/1/2020      F   62  Princess Margaret Hospital
# 3         4   24/1/2020     23/1/2020      F   62  Princess Margaret Hospital
# 4         5   24/1/2020     23/1/2020      M   63  Princess Margaret Hospital
# 5         6   26/1/2020     21/1/2020      M   47  Princess Margaret Hospital
# 6         7   26/1/2020     21/1/2020      F   68  Princess Margaret Hospital
# 7         8   26/1/2020     25/1/2020      M   64  Princess Margaret Hospital
# 8         9   29/1/2020     25/1/2020      F   73  Princess Margaret Hospital
# 9        10   29/1/2020     25/1/2020      M   72  Princess Margaret Hospital
#
#   Hospitalised/Discharged/Deceased HK/Non-HK resident Case classification*  \
# ...

# %% [markdown]
# explore gender, local/non-local resident, case classification. Maybe to find out some relationship between them?

# %% [markdown]
# # Foursquare data

# %% [markdown]
# It will used to search the best rated hotel in different district, that is best suited for business trip in Hong Kong.
