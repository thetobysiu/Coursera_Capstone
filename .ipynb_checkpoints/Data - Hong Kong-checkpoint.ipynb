# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def sent_trim(string):
    string = re.sub(r'\r', ' ', string)
    string = re.sub(r'\n', ' ', string)
    string = re.sub(r'[-_]+', ' ', string)
    string = re.sub(r' +', ' ', string)
    string = re.sub(r'^ *([oV] )', ' ', string)
    string = re.sub(r'^[^\w.,!?%:/()&@;-]+', '', string)
    string = re.sub(r'[^\w.,!?%:/()）。&@;]+$', '', string)
    return string

# %%
html = requests.get('https://en.wikipedia.org/wiki/List_of_MTR_stations')

# %%
soup = BeautifulSoup(html.text, 'html5lib')

# %%
# remove some extra explanatory text under some stations, e.g. formerly...
for small in soup.find_all("small"): 
    small.decompose()

# %%
tables = soup.find_all('table', class_='wikitable sortable')

# %%
mtr_stations_df_list = pd.read_html(str(tables))
mtr_stations_df = pd.concat(mtr_stations_df_list)
mtr_stations_df = mtr_stations_df[['District', 'Name']].drop_duplicates().sort_values('District').reset_index(drop=True)
mtr_stations_df.columns = ['District', 'Station']

# %%
mtr_stations_df
# Out:
#                       District             Station
# 0          Central and Western           Hong Kong
# 1          Central and Western           Admiralty
# 2          Central and Western             Central
# 3          Central and Western        Kennedy Town
# 4          Central and Western                 HKU
# 5          Central and Western        Sai Ying Pun
# 6          Central and Western          Sheung Wan
# 7                      Eastern             Tin Hau
# 8                      Eastern         North Point
# 9                      Eastern          Quarry Bay
# 10                     Eastern       Fortress Hill
# 11                     Eastern          Sai Wan Ho
# 12                     Eastern        Shau Kei Wan
# 13                     Eastern       Heng Fa Chuen
# 14                     Eastern            Chai Wan
# 15                     Eastern             Tai Koo
# 16                     Islands             Airport
# 17                     Islands          Tung Chung
# 18                     Islands      AsiaWorld–Expo
# 19                Kowloon City             Whampoa
# 20                Kowloon City          Ho Man Tin
# 21                Kowloon City             Kai Tak
# 22                  Kwai Tsing           Kwai Fong
# 23                  Kwai Tsing            Tsing Yi
# 24                  Kwai Tsing            Lai King
# 25                  Kwai Tsing           Kwai Hing
# 26        Kwai Tsing/Tsuen Wan          Tai Wo Hau
# 27                   Kwun Tong             Lam Tin
# 28                   Kwun Tong            Yau Tong
# 29                   Kwun Tong           Kwun Tong
# 30                   Kwun Tong        Ngau Tau Kok
# 31                   Kwun Tong         Kowloon Bay
# 32                       North         Sheung Shui
# 33                       North             Fanling
# 34                       North               Lo Wu
# 35                    Sai Kung       Tiu Keng Leng
# 36                    Sai Kung       Tseung Kwan O
# 37                    Sai Kung          LOHAS Park
# 38                    Sai Kung            Hang Hau
# 39                    Sai Kung              Po Lam
# 40                     Sha Tin         Sha Tin Wai
# 41                     Sha Tin              Fo Tan
# 42                     Sha Tin            Hin Keng
# 43                     Sha Tin     Che Kung Temple
# 44                     Sha Tin          Wu Kai Sha
# 45                     Sha Tin            City One
# 46                     Sha Tin          Racecourse
# 47                     Sha Tin             Tai Wai
# 48                     Sha Tin       Tai Shui Hang
# 49                     Sha Tin             Heng On
# 50                     Sha Tin          Ma On Shan
# 51                     Sha Tin          University
# 52                     Sha Tin            Shek Mun
# 53                     Sha Tin             Sha Tin
# 54                Sham Shui Po             Mei Foo
# 55                Sham Shui Po          Nam Cheong
# 56                Sham Shui Po        Sham Shui Po
# 57                Sham Shui Po      Cheung Sha Wan
# 58                Sham Shui Po         Lai Chi Kok
# 59                Sham Shui Po        Shek Kip Mei
# 60   Sham Shui Po/Kowloon City        Kowloon Tong
# 61                    Southern      South Horizons
# 62                    Southern            Lei Tung
# 63                    Southern          Ocean Park
# 64                    Southern      Wong Chuk Hang
# 65                      Tai Po              Tai Wo
# 66                      Tai Po       Tai Po Market
# 67                   Tsuen Wan           Sunny Bay
# 68                   Tsuen Wan      Tsuen Wan West
# 69                   Tsuen Wan   Disneyland Resort
# 70                   Tsuen Wan           Tsuen Wan
# 71                    Tuen Mun            Siu Hong
# 72                    Tuen Mun            Tuen Mun
# 73                    Wan Chai            Wan Chai
# 74                    Wan Chai        Causeway Bay
# 75                Wong Tai Sin              Lok Fu
# 76                Wong Tai Sin        Wong Tai Sin
# 77                Wong Tai Sin        Diamond Hill
# 78      Wong Tai Sin/Kwun Tong           Choi Hung
# 79               Yau Tsim Mong          Yau Ma Tei
# 80               Yau Tsim Mong            Mong Kok
# 81               Yau Tsim Mong       Prince Edward
# 82               Yau Tsim Mong             Olympic
# 83               Yau Tsim Mong              Austin
# 84               Yau Tsim Mong              Jordan
# 85               Yau Tsim Mong       Tsim Sha Tsui
# 86               Yau Tsim Mong             Kowloon
# 87               Yau Tsim Mong  East Tsim Sha Tsui
# 88  Yau Tsim Mong/Kowloon City            Hung Hom
# 89  Yau Tsim Mong/Kowloon City       Mong Kok East
# 90                   Yuen Long     Kam Sheung Road
# 91                   Yuen Long           Yuen Long
# 92                   Yuen Long           Long Ping
# 93                   Yuen Long        Tin Shui Wai
# 94                   Yuen Long         Lok Ma Chau

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="tor_explorer")

# %%
def get_lat_long(address):
    location = geolocator.geocode(f'{address}, HK')
    try:
        return location.latitude, location.longitude
    except AttributeError:
        return 0, 0

# %%
def append_lat_long(series):
    lat, long = get_lat_long(f"{series['Station']} Station")
    series['Latitude'] = lat
    series['Longitude'] = long
    return series

# %%
mtr_stations_df = mtr_stations_df.apply(append_lat_long, axis=1)

# %%
mtr_stations_df = mtr_stations_df[mtr_stations_df['Latitude'] != 0]

# %%
mtr_stations_df
# Out:
#                       District             Station   Latitude   Longitude
# 0          Central and Western           Hong Kong  22.279328  114.162813
# 1          Central and Western           Admiralty  22.278381  114.165013
# 2          Central and Western             Central  22.350627  114.184916
# 3          Central and Western        Kennedy Town  22.281363  114.127832
# 4          Central and Western                 HKU  22.283976  114.135507
# 5          Central and Western        Sai Ying Pun  22.286121  114.142086
# 6          Central and Western          Sheung Wan  22.285899  114.153707
# 57                Sham Shui Po      Cheung Sha Wan  22.335340  114.157790
# 58                Sham Shui Po         Lai Chi Kok  22.337224  114.148310
# 59                Sham Shui Po        Shek Kip Mei  22.331801  114.167995
# 60   Sham Shui Po/Kowloon City        Kowloon Tong  22.336292  114.176954
# 61                    Southern      South Horizons  22.243901  114.149771
# 62                    Southern            Lei Tung  22.241955  114.156017
# 63                    Southern          Ocean Park  22.246751  114.173956
# 64                    Southern      Wong Chuk Hang  22.248258  114.168425
# 65                      Tai Po              Tai Wo  22.451010  114.160773
# 66                      Tai Po       Tai Po Market  22.443817  114.169128
# 67                   Tsuen Wan           Sunny Bay  22.332859  114.028403
# 68                   Tsuen Wan      Tsuen Wan West  22.368637  114.109851
# 69                   Tsuen Wan   Disneyland Resort  22.315376  114.045146
# 70                   Tsuen Wan           Tsuen Wan  22.373674  114.117757
# 71                    Tuen Mun            Siu Hong  22.410339  113.978204
# 72                    Tuen Mun            Tuen Mun  22.394880  113.974482
# 73                    Wan Chai            Wan Chai  22.279015  114.172483
# 74                    Wan Chai        Causeway Bay  22.280208  114.184841
# 75                Wong Tai Sin              Lok Fu  22.337983  114.186947
# 76                Wong Tai Sin        Wong Tai Sin  22.341803  114.192191
# 77                Wong Tai Sin        Diamond Hill  22.339489  114.202883
# 78      Wong Tai Sin/Kwun Tong           Choi Hung  22.334068  114.210044
# 79               Yau Tsim Mong          Yau Ma Tei  22.312365  114.170779
# 80               Yau Tsim Mong            Mong Kok  22.320130  114.169314
# 81               Yau Tsim Mong       Prince Edward  22.325860  114.168128
# 82               Yau Tsim Mong             Olympic  22.318603  114.160511
# 83               Yau Tsim Mong              Austin  22.306364  114.164398
# 84               Yau Tsim Mong              Jordan  22.305011  114.171740
# 85               Yau Tsim Mong       Tsim Sha Tsui  22.298872  114.174118
# 86               Yau Tsim Mong             Kowloon  22.304756  114.163185
# 87               Yau Tsim Mong  East Tsim Sha Tsui  22.295166  114.174589
# 88  Yau Tsim Mong/Kowloon City            Hung Hom  22.304790  114.182099
# 89  Yau Tsim Mong/Kowloon City       Mong Kok East  22.322672  114.172233
# 90                   Yuen Long     Kam Sheung Road  22.434648  114.064956
# 91                   Yuen Long           Yuen Long  22.446021  114.034944
# 92                   Yuen Long           Long Ping  22.447670  114.025449
# 93                   Yuen Long        Tin Shui Wai  22.459611  114.002238
# 94                   Yuen Long         Lok Ma Chau  22.515505  114.066628

# %%
mtr_stations_df.to_csv('stations.csv', index=False)

# %%
import folium

# %%
get_lat_long('Hong Kong')
# Out:
# (22.2793278, 114.1628131)

# %%
map_hk = folium.Map(location=get_lat_long('Hong Kong'), zoom_start=10.5)

# add markers to map
for lat, lng, district, station in zip(mtr_stations_df['Latitude'], mtr_stations_df['Longitude'], mtr_stations_df['District'], mtr_stations_df['Station']):
    label = '{}, {}'.format(station, district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hk)

map_hk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
